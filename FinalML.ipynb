# %%
import pandas as pd
import numpy as np

# %%
import cv2
import PIL

# %%
from PIL import Image

PIL.Image.open('archive (4)/train/FAKE/1011 (9).jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=32x32>

# %%
image = cv2.imread('archive (4)/train/FAKE/1011 (9).jpg')
image.shape
# Out:
# (32, 32, 3)

# %%
train_path_fake =[]

base_1 = 'archive (4)/train/FAKE/'

for i in range(1000,6000):
    a = '{}{}.jpg'.format(base_1, i)
    train_path_fake.append(a)

for i in range(1000,6000):
    for j in range(2,11):
        b = '{}{} ({}).jpg'.format(base_1, i, j)
        train_path_fake.append(b)
len(train_path_fake)
# Out:
# 50000

# %%
df_train_fake = pd.DataFrame(train_path_fake)
df_train_fake.columns = ['path']
df_train_fake['label'] = 0
df_train_fake.head()
# Out:
#                               path  label
# 0  archive (4)/train/FAKE/1000.jpg      0
# 1  archive (4)/train/FAKE/1001.jpg      0
# 2  archive (4)/train/FAKE/1002.jpg      0
# 3  archive (4)/train/FAKE/1003.jpg      0
# 4  archive (4)/train/FAKE/1004.jpg      0

# %%
train_path_real=[]

base_2 = 'archive (4)/train/REAL/'

for i in range(0,10):
    c = '{}000{}.jpg'.format(base_2, i)
    train_path_real.append(c)

for i in range(0,10):
    for j in range(2,11):
        d = '{}000{} ({}).jpg'.format(base_2, i,j)
        train_path_real.append(d)
len(train_path_real)
# Out:
# 100

# %%
for i in range(10,100):
    e = '{}00{}.jpg'.format(base_2, i)
    train_path_real.append(e)


for i in range(10,100):
    for j in range(2,11):
        f = '{}00{} ({}).jpg'.format(base_2, i,j)
        train_path_real.append(f)
len(train_path_real)
# Out:
# 1000

# %%
for i in range(100,1000):
    g = '{}0{}.jpg'.format(base_2, i)
    train_path_real.append(g)

for i in range(100,1000):
    for j in range(2,11):
        h = '{}0{} ({}).jpg'.format(base_2, i,j)
        train_path_real.append(h)
len(train_path_real)
# Out:
# 10000

# %%
for i in range(1000,5000):
    k = '{}{}.jpg'.format(base_2, i)
    train_path_real.append(k)

for i in range(1000,5000):
    for j in range(2,11):
        l = '{}{} ({}).jpg'.format(base_2, i,j)
        train_path_real.append(l)
len(train_path_real)
# Out:
# 50000

# %%
df_train_real = pd.DataFrame(train_path_real)
df_train_real.columns = ['path']
df_train_real['label'] = 1
df_train_real.head()
# Out:
#                               path  label
# 0  archive (4)/train/REAL/0000.jpg      1
# 1  archive (4)/train/REAL/0001.jpg      1
# 2  archive (4)/train/REAL/0002.jpg      1
# 3  archive (4)/train/REAL/0003.jpg      1
# 4  archive (4)/train/REAL/0004.jpg      1

# %%
df_train = pd.concat((df_train_fake, df_train_real), axis = 0 )
print(df_train.shape)
df_train.sample(5)
# Out:
# (100000, 2)
#                                        path  label
# 33673  archive (4)/train/REAL/3185 (10).jpg      1
# 6778    archive (4)/train/REAL/0642 (2).jpg      1
# 22516   archive (4)/train/REAL/1946 (4).jpg      1
# 13402       archive (4)/train/REAL/4402.jpg      1
# 19281   archive (4)/train/FAKE/2586 (9).jpg      0

# %%
image_df = []
for image in df_train['path']:
    img = cv2.imread(image)
    resized = cv2.resize(img,(32,32))
    image_df.append(resized)
image_array = np.array(image_df)
X_train = image_array/255
X_train.ndim
# Out:
# 4

# %%
y_train = df_train['label']
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
test_path_fake =[]

base_3 = 'archive (4)/test/FAKE/'

for i in range(0,1000):
    m = '{}{}.jpg'.format(base_3, i)
    test_path_fake.append(m)
    
for i in range(0,1000):
    for j in range(2,11):
        n = '{}{} ({}).jpg'.format(base_3, i, j)
        test_path_fake.append(n)
len(test_path_fake)
# Out:
# 10000

# %%
df_test_fake = pd.DataFrame(test_path_fake)
df_test_fake.columns = ['path']
df_test_fake['label'] = 0
df_test_fake.head()
# Out:
#                           path  label
# 0  archive (4)/test/FAKE/0.jpg      0
# 1  archive (4)/test/FAKE/1.jpg      0
# 2  archive (4)/test/FAKE/2.jpg      0
# 3  archive (4)/test/FAKE/3.jpg      0
# 4  archive (4)/test/FAKE/4.jpg      0

# %%
test_path_real =[]

base_4 = 'archive (4)/test/REAL/'

for i in range(0,10):
    o = '{}000{}.jpg'.format(base_4, i)
    test_path_real.append(o)

for i in range(0,10):
    for j in range(2,11):
        p = '{}000{} ({}).jpg'.format(base_4, i,j)
        test_path_real.append(p)
len(test_path_real)
100
# Out:
# 100

# %%
for i in range(10,100):
    q = '{}00{}.jpg'.format(base_4, i)
    test_path_real.append(q)

for i in range(10,100):
    for j in range(2,11):
        r = '{}00{} ({}).jpg'.format(base_4, i,j)
        test_path_real.append(r)
len(test_path_real)
# Out:
# 1000

# %%
for i in range(100,1000):
    s = '{}0{}.jpg'.format(base_4, i)
    test_path_real.append(s)
    
for i in range(100,1000):
    for j in range(2,11):
        t = '{}0{} ({}).jpg'.format(base_4, i,j)
        test_path_real.append(t)
len(test_path_real)
# Out:
# 10000

# %%
df_test_real = pd.DataFrame(test_path_real)
df_test_real.columns = ['path']
df_test_real['label'] = 1
df_test_real.head()
# Out:
#                              path  label
# 0  archive (4)/test/REAL/0000.jpg      1
# 1  archive (4)/test/REAL/0001.jpg      1
# 2  archive (4)/test/REAL/0002.jpg      1
# 3  archive (4)/test/REAL/0003.jpg      1
# 4  archive (4)/test/REAL/0004.jpg      1

# %%
df_test = pd.concat((df_test_fake, df_test_real), axis = 0 )
print(df_test.shape)
df_test.sample(5)
# Out:
# (20000, 2)
#                                     path  label
# 3619   archive (4)/test/FAKE/291 (2).jpg      0
# 4054   archive (4)/test/FAKE/339 (5).jpg      0
# 4209   archive (4)/test/FAKE/356 (7).jpg      0
# 8284  archive (4)/test/REAL/0809 (5).jpg      1
# 4400  archive (4)/test/REAL/0377 (9).jpg      1

# %%
image_ds = []
for image in df_test['path']:
    imge = cv2.imread(image)
    resize = cv2.resize(imge,(32,32))
    image_ds.append(resize)
image_arry = np.array(image_ds)
X_test = image_arry/255
X_test.ndim
# Out:
# 4

# %%
y_test = df_test['label']
y_test.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
from tensorflow.keras import models , layers

model = models.Sequential([
    layers.Conv2D(filters = 80 , kernel_size = (3,3),activation = 'elu',input_shape= (32,32,3)),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(filters = 40 , kernel_size = (3,3),activation = 'elu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(filters = 20 , kernel_size = (3,3),activation = 'elu'),
    layers.MaxPool2D((2,2)),
    
    layers.Flatten(),
    layers.Dense(10,activation = 'elu'),
    layers.Dense(2,activation = 'sigmoid'),
                         ])

model.compile(
    optimizer = 'adam',
    loss= 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
             )

model.fit(X_train,y_train, epochs = 5)
# Out:
# Epoch 1/5
# 3125/3125 [==============================] - 52s 17ms/step - loss: 0.3444 - accuracy: 0.8467
# Epoch 2/5
# 3125/3125 [==============================] - 52s 17ms/step - loss: 0.2449 - accuracy: 0.8997
# Epoch 3/5
# 3125/3125 [==============================] - 52s 17ms/step - loss: 0.2174 - accuracy: 0.9128
# Epoch 4/5
# 3125/3125 [==============================] - 53s 17ms/step - loss: 0.1975 - accuracy: 0.9219
# Epoch 5/5
# 3125/3125 [==============================] - 53s 17ms/step - loss: 0.1865 - accuracy: 0.9265

# %%
model.evaluate(X_test,y_test)
# Out:
# 625/625 [==============================] - 3s 5ms/step - loss: 0.1927 - accuracy: 0.9238
# [0.19269558787345886, 0.9238499999046326]

# %%
y_pred  = model.predict(X_test)
# Out:
# 625/625 [==============================] - 3s 5ms/step

# %%
y_pred_label = [np.argmax(i) for i in y_pred]
y_pred_label[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
from sklearn.metrics import classification_report

print('Classification Report     : \n\n\n' , classification_report(y_test,y_pred_label))
# Out:
# Classification Report     :
#
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93     10000
#            1       0.95      0.90      0.92     10000
#
#     accuracy                           0.92     20000
#    macro avg       0.92      0.92      0.92     20000
# weighted avg       0.92      0.92      0.92     20000

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test , y_pred_label)

# %%
import matplotlib.pyplot as plt
import seaborn as sn


plt.figure(figsize=(4,4), facecolor= 'pink', edgecolor='brown')
sn.heatmap(cm , annot= True, fmt="d")
plt.xlabel('Prediction', fontdict= {'family':'fantasy','color':'black','size':15})
plt.ylabel('Truth', fontdict= {'family':'fantasy','color':'black','size':15})
plt.title('Confusion Matrix',fontdict= {'family':'fantasy','color':'red','size':20})
plt.show()

# %%
def predict_image(image_path):
    img = cv2.imread(image_path)
    resized_img = cv2.resize(img, (32, 32))
    processed_img = resized_img / 255.0  # Normalize the image
    processed_img = np.expand_dims(processed_img, axis=0)  # Add batch dimension

    # Use your trained model to predict
    prediction = model.predict(processed_img)
    if prediction[0][0] > prediction[0][1]:
        return "Fake"
    else:
        return "Real"

# %%
predict_image("_131125206_f56bff9a-3b44-47eb-97cd-b1753de4f877.jpg")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 'Fake'
